# %% [markdown]
# # 05 — Error Analysis
# Worst-K predictions per subgroup and heuristic tag frequencies.

# %%
import sys
from pathlib import Path
ROOT = Path().resolve().parent
sys.path.insert(0, str(ROOT))
import pandas as pd
from src import config

# %% [markdown]
# ## Tag frequencies per subgroup (retrieval)

# %%
pd.read_csv(config.TABLES / 'error_analysis' / 'tag_frequencies_retrieval_by_priority.csv')

# %%
pd.read_csv(config.TABLES / 'error_analysis' / 'tag_frequencies_retrieval_by_queue.csv')

# %% [markdown]
# ## Worst-K examples (retrieval, by department)

# %%
worst = pd.read_csv(config.SAMPLES / 'worst_retrieval_by_queue.csv')
worst.head(20)

# %% [markdown]
# Next step (deferred): manually label 100 stratified samples to populate the failure taxonomy described in `METHODOLOGY.md`.
